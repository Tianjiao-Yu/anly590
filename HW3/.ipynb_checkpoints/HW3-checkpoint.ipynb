# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow_datasets as tfds
tfkl = tfk.layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## 1. Autocoder

# %%
# load the CIFAR10 dataset
data,info = tfds.load('cifar10', with_info=True)

# %%
preprocess = lambda d: (tf.cast(d['image'], tf.float32)/255., d['label'])
df_train = data['train'].map(preprocess).map(lambda x, y: (x, x)).cache().batch(32).repeat().prefetch(5)
df_test = data['test'].map(preprocess)

img_shape = info.features['image'].shape
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x156f72940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x156f72940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x156f72940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
encoder = tfk.Sequential([
    tfkl.InputLayer(img_shape),
    tfkl.Conv2D(32,(3,3), activation=tf.nn.relu, padding="same"),
    tfkl.MaxPooling2D((2,2), padding="same"),
    tfkl.Conv2D(16,(3,3), activation=tf.nn.relu, padding="same"),
    tfkl.MaxPooling2D((2,2), padding="same"),
    tfkl.Conv2D(16, (3, 3), activation=tf.nn.relu, padding="same"),
    tfkl.MaxPooling2D((2,2), padding="same"),
])

encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 16)          2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 16)          0
# =================================================================
# Total params: 7,840
# Trainable params: 7,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder = tfk.Sequential([
    tfkl.InputLayer((4, 4, 16)),
    tfkl.Conv2D(8,(3, 3), activation=tf.nn.relu, padding="same"),
    tfkl.UpSampling2D((2, 2)),
    tfkl.Conv2D(16, (3, 3), activation=tf.nn.relu, padding="same"),
    tfkl.UpSampling2D((2, 2)),
    tfkl.Conv2D(32, (3, 3), activation=tf.nn.relu, padding="same"),
    tfkl.UpSampling2D((2, 2)),
    tfkl.Conv2D(3, (3, 3), activation=tf.nn.relu, padding="same")
])

decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 4, 4, 8)           1160
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 16)          1168
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 3)         867
# =================================================================
# Total params: 7,835
# Trainable params: 7,835
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = tfkl.Input(img_shape)
h = encoder(x)
xhat = decoder(h)
autoencoder = tfk.Model(inputs=x, outputs=xhat)
autoencoder.summary()

autoencoder.compile(
    optimizer=tfk.optimizers.Adam(),
    loss=tfk.losses.BinaryCrossentropy(),
)

results = autoencoder.fit(df_train, steps_per_epoch=400, epochs=10)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# sequential (Sequential)      (None, 4, 4, 16)          7840
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 32, 32, 3)         7835
# =================================================================
# Total params: 15,675
# Trainable params: 15,675
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 400/400 [==============================] - 26s 66ms/step - loss: 0.6935
# Epoch 2/10
# 400/400 [==============================] - 27s 67ms/step - loss: 0.6150
# Epoch 3/10
# 400/400 [==============================] - 27s 68ms/step - loss: 0.5991
# Epoch 4/10
# 400/400 [==============================] - 27s 68ms/step - loss: 0.5935
# Epoch 5/10
# 400/400 [==============================] - 27s 67ms/step - loss: 0.5985
# Epoch 6/10
# 400/400 [==============================] - 27s 67ms/step - loss: 0.6010
# Epoch 7/10
# 400/400 [==============================] - 27s 68ms/step - loss: 0.5934
# Epoch 8/10
# 400/400 [==============================] - 27s 67ms/step - loss: 0.5939
# Epoch 9/10
# 400/400 [==============================] - 27s 67ms/step - loss: 0.5955
# Epoch 10/10
# 400/400 [==============================] - 27s 68ms/step - loss: 0.5894

# %%
imgs = next(iter(df_train))[0]
for i in range(10):
    plt.subplot(1, 2, 1)
    plt.imshow(imgs[i].numpy().squeeze(), cmap='bone')
    plt.subplot(1, 2, 2, )
    plt.imshow(autoencoder(imgs[i][tf.newaxis]).numpy().squeeze(), cmap='bone')
    plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## 2.1 Deep CNN

# %%
model = tfk.Sequential([
    tfkl.InputLayer(img_shape),
    tfkl.Conv2D(filters = 32, kernel_size= 2, strides= 1, padding= "valid",
                           activation = 'relu'),
    tfkl.MaxPooling2D((2, 2)),
    tfkl.Conv2D(filters = 64, kernel_size= 2, strides= 1, padding= "valid", activation= 'relu'),
    tfkl.MaxPooling2D((2, 2)),
    tfkl.Conv2D(filters = 64, kernel_size= 2, strides= 1, padding= "valid", activation= 'relu'),
    tfkl.Flatten(),
    tfkl.Dense(64, activation= 'relu'),
    tfkl.Dense(10, activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 31, 31, 32)        416
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 64)        8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 64)          16448
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 173,290
# Trainable params: 173,290
# Non-trainable params: 0
# _________________________________________________________________

# %%
preprocess = lambda d: (tf.cast(d["image"], tf.float32)/255, tf.one_hot(d["label"], depth=10))

ds_train = data['train'].map(preprocess).cache().batch(8)
ds_test = data["test"].map(preprocess).cache().batch(8)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x157ecdd30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x157ecdd30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x157ecdd30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
model.compile(optimizer=tfk.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])


history = model.fit(ds_train, epochs=10, validation_data=(ds_test))
# Out:
# Epoch 1/10
# 6250/6250 [==============================] - 41s 7ms/step - loss: 1.4095 - accuracy: 0.4911 - val_loss: 1.1132 - val_accuracy: 0.6066
# Epoch 2/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 1.0529 - accuracy: 0.6302 - val_loss: 0.9906 - val_accuracy: 0.6495
# Epoch 3/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.9083 - accuracy: 0.6811 - val_loss: 0.9508 - val_accuracy: 0.6722
# Epoch 4/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.8158 - accuracy: 0.7168 - val_loss: 0.9453 - val_accuracy: 0.6819
# Epoch 5/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.7471 - accuracy: 0.7405 - val_loss: 0.9482 - val_accuracy: 0.6902
# Epoch 6/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.6906 - accuracy: 0.7607 - val_loss: 0.9967 - val_accuracy: 0.6839
# Epoch 7/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.6401 - accuracy: 0.7780 - val_loss: 1.0277 - val_accuracy: 0.6854
# Epoch 8/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.5976 - accuracy: 0.7913 - val_loss: 1.1249 - val_accuracy: 0.6680
# Epoch 9/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.5590 - accuracy: 0.8043 - val_loss: 1.1518 - val_accuracy: 0.6718
# Epoch 10/10
# 6250/6250 [==============================] - 38s 6ms/step - loss: 0.5251 - accuracy: 0.8165 - val_loss: 1.2483 - val_accuracy: 0.6672

# %%
# evaluate the model
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
test_loss, test_acc = model.evaluate(ds_test,verbose=1)
print('\nTest accuracy:', test_acc)
# Out:
# 1250/1250 [==============================] - 1s 947us/step - loss: 1.2483 - accuracy: 0.6672
#
# Test accuracy: 0.6672000288963318

# %% [markdown]
# ## 2.2 Transfer learning

# %%
base_model = tfk.applications.ResNet50(input_shape=(32, 32, 3),
                                include_top=False,
                                weights='imagenet')
base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step

# %%
image_batch = tfk.Input(shape=(32,32,3))
feature_batch = base_model(image_batch)

global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
prediction_layer = tfkl.Dense(10, activation="softmax")
outputs = prediction_layer(feature_batch_average)

# %%
model1 = tfk.Model(image_batch, outputs)

base_learning_rate = 0.001
model1.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
history1 = model1.fit(ds_train, epochs=10, validation_data=ds_test)
# Out:
# Epoch 1/10
# 6250/6250 [==============================] - 172s 28ms/step - loss: 0.7309 - accuracy: 0.2004 - val_loss: 0.7267 - val_accuracy: 0.2639
# Epoch 2/10
# 6250/6250 [==============================] - 173s 28ms/step - loss: 0.7270 - accuracy: 0.2543 - val_loss: 0.7250 - val_accuracy: 0.2821
# Epoch 3/10
# 6250/6250 [==============================] - 174s 28ms/step - loss: 0.7254 - accuracy: 0.2727 - val_loss: 0.7239 - val_accuracy: 0.2947
# Epoch 4/10
# 6250/6250 [==============================] - 175s 28ms/step - loss: 0.7245 - accuracy: 0.2847 - val_loss: 0.7231 - val_accuracy: 0.3033
# Epoch 5/10
# 6250/6250 [==============================] - 175s 28ms/step - loss: 0.7238 - accuracy: 0.2919 - val_loss: 0.7224 - val_accuracy: 0.3094
# Epoch 6/10
# 6250/6250 [==============================] - 176s 28ms/step - loss: 0.7233 - accuracy: 0.2981 - val_loss: 0.7221 - val_accuracy: 0.3154
# Epoch 7/10
# 6250/6250 [==============================] - 176s 28ms/step - loss: 0.7229 - accuracy: 0.3014 - val_loss: 0.7220 - val_accuracy: 0.3140
# Epoch 8/10
# 6250/6250 [==============================] - 177s 28ms/step - loss: 0.7226 - accuracy: 0.3046 - val_loss: 0.7219 - val_accuracy: 0.3145
# Epoch 9/10
# 6250/6250 [==============================] - 178s 28ms/step - loss: 0.7223 - accuracy: 0.3077 - val_loss: 0.7217 - val_accuracy: 0.3162
# Epoch 10/10
# 6250/6250 [==============================] - 178s 28ms/step - loss: 0.7220 - accuracy: 0.3114 - val_loss: 0.7215 - val_accuracy: 0.3191

# %%
# evaluate the model
plt.plot(history1.history['accuracy'], label='accuracy')
plt.plot(history1.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 0.5])
plt.legend(loc='lower right')

# %%
test_loss, test_acc = model1.evaluate(ds_test,verbose=2)
print('Test accuracy:', test_acc)
# Out:
# 1250/1250 - 30s - loss: 0.7215 - accuracy: 0.3191
# Test accuracy: 0.3190999925136566

# %% [markdown]
# ## 3.1RNN

# %%
df = pd.read_csv("../SPAM_detection.csv")
df.head()
# Out:
#                                              Message  category_val
# 0  Go until jurong point, crazy.. Available only ...             0
# 1                      Ok lar... Joking wif u oni...             0
# 2  Free entry in 2 a wkly comp to win FA Cup fina...             1
# 3  U dun say so early hor... U c already then say...             0
# 4  Nah I don't think he goes to usf, he lives aro...             0

# %%
text = df['Message'].str.lower()
chars = sorted(list(set(text)))
print('total chars:', len(chars))
# Out:
# total chars: 5156

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

cv = CountVectorizer(stop_words="english", max_features = 1000)
X = cv.fit_transform(text).toarray()
Y = df["category_val"].values
X = X[:,:,None]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model3 = tfk.Sequential()
model3.add(tfkl.GRU(32,input_shape = X_train.shape[1:]))
model3.add(tfkl.Dense(8, activation="relu"))
model3.add(tfkl.Dense(1, activation="sigmoid"))
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 32)                3360
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 3,633
# Trainable params: 3,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(optimizer=tfk.optimizers.Adam(), 
               loss=tfk.losses.BinaryCrossentropy(),
               metrics=["accuracy"])

# %%
model3.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 35s 249ms/step - loss: 0.4426 - accuracy: 0.8658 - val_loss: 0.3956 - val_accuracy: 0.8664
# Epoch 2/10
# 140/140 [==============================] - 32s 227ms/step - loss: 0.3967 - accuracy: 0.8658 - val_loss: 0.3991 - val_accuracy: 0.8664
# Epoch 3/10
# 140/140 [==============================] - 30s 217ms/step - loss: 0.3965 - accuracy: 0.8658 - val_loss: 0.3968 - val_accuracy: 0.8664
# Epoch 4/10
# 140/140 [==============================] - 30s 215ms/step - loss: 0.3967 - accuracy: 0.8658 - val_loss: 0.4051 - val_accuracy: 0.8664
# Epoch 5/10
# 140/140 [==============================] - 30s 215ms/step - loss: 0.3956 - accuracy: 0.8658 - val_loss: 0.3936 - val_accuracy: 0.8664
# Epoch 6/10
# 140/140 [==============================] - 30s 214ms/step - loss: 0.3953 - accuracy: 0.8658 - val_loss: 0.3932 - val_accuracy: 0.8664
# Epoch 7/10
# 140/140 [==============================] - 30s 215ms/step - loss: 0.3947 - accuracy: 0.8658 - val_loss: 0.3927 - val_accuracy: 0.8664
# Epoch 8/10
# 140/140 [==============================] - 30s 214ms/step - loss: 0.3950 - accuracy: 0.8658 - val_loss: 0.3937 - val_accuracy: 0.8664
# Epoch 9/10
# 140/140 [==============================] - 30s 214ms/step - loss: 0.3941 - accuracy: 0.8658 - val_loss: 0.3923 - val_accuracy: 0.8664
# Epoch 10/10
# 140/140 [==============================] - 30s 214ms/step - loss: 0.3961 - accuracy: 0.8658 - val_loss: 0.3934 - val_accuracy: 0.8664

# %% [markdown]
# ## 3.2 CNN

# %%
model4 = tfk.Sequential([
    tfkl.Conv1D(filters= 32,kernel_size= 2,strides= 1,padding='valid',input_shape= (X_train.shape[1:]),
                activation= 'relu'),
    tfkl.MaxPooling1D(pool_size = 2),
    tfkl.Conv1D(filters = 64, kernel_size= 2,strides= 1,padding='valid', activation= 'relu'),
    tfkl.Flatten(),
    tfkl.Dense(64,activation='relu'),
    tfkl.Dense(1,activation='sigmoid')                     
])

model4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 999, 32)           96
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 499, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 498, 64)           4160
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 31872)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                2039872
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,044,193
# Trainable params: 2,044,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4.compile(optimizer=tfk.optimizers.Adam(),
               loss=tfk.losses.BinaryCrossentropy(),
               metrics=["accuracy"])

# %%
model4.fit(X_train,y_train, epochs = 10, validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 4s 29ms/step - loss: 0.1369 - accuracy: 0.9569 - val_loss: 0.0576 - val_accuracy: 0.9865
# Epoch 2/10
# 140/140 [==============================] - 4s 26ms/step - loss: 0.0436 - accuracy: 0.9870 - val_loss: 0.0565 - val_accuracy: 0.9839
# Epoch 3/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0311 - accuracy: 0.9906 - val_loss: 0.0634 - val_accuracy: 0.9848
# Epoch 4/10
# 140/140 [==============================] - 3s 25ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.0743 - val_accuracy: 0.9865
# Epoch 5/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0179 - accuracy: 0.9953 - val_loss: 0.0818 - val_accuracy: 0.9830
# Epoch 6/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0120 - accuracy: 0.9971 - val_loss: 0.0861 - val_accuracy: 0.9821
# Epoch 7/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.0904 - val_accuracy: 0.9857
# Epoch 8/10
# 140/140 [==============================] - 3s 24ms/step - loss: 0.0089 - accuracy: 0.9982 - val_loss: 0.1008 - val_accuracy: 0.9865
# Epoch 9/10
# 140/140 [==============================] - 4s 30ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.1427 - val_accuracy: 0.9857
# Epoch 10/10
# 140/140 [==============================] - 4s 26ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.1144 - val_accuracy: 0.9865

# %% [markdown]
# ## 3.3 Comparision

# %%
# plot the ROC curve
from sklearn.metrics import roc_curve, auc
rnn_test = model3.predict(X_test)[:,0]
cnn_test = model4.predict(X_test)[:,0]
target = y_test[:]>0

# %%
fpr_rnn, tpr_rnn, _ = roc_curve(target, rnn_test)
fpr_cnn, tpr_cnn ,_ = roc_curve(target, cnn_test)

plt.plot(fpr_rnn, tpr_rnn, label='ROC curve for RNN (area = %0.2f)' % auc(fpr_rnn,tpr_rnn))
plt.plot(fpr_cnn, tpr_cnn, label='ROC curve for CNN (area = %0.2f)' % auc(fpr_cnn,tpr_cnn))
plt.plot([0, 1], [0, 1], color='gray',linestyle='--')
plt.xlim([-0.02, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve: RNN vs CNN')
plt.legend(loc="lower right")
plt.show()
